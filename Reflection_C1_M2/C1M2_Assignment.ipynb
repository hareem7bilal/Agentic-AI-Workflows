# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    Write a complete, well-structured essay on the following topic: {topic}

    The essay should include:
    - An engaging introduction that presents the topic and thesis
    - Multiple body paragraphs with clear arguments and supporting evidence
    - A strong conclusion that summarizes the main points
    
    Make the essay comprehensive, coherent, and around 500-700 words in length.
    Use formal academic writing style.
    """

    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are an experienced writing tutor. Please review the following essay draft and provide constructive, critical feedback.

    Essay Draft:
    {draft}

    Analyze the essay and provide feedback in paragraph form addressing the following aspects:
    - Overall structure and organization
    - Clarity and coherence of ideas
    - Strength and persuasiveness of arguments
    - Writing style and tone
    - Areas that need improvement or elaboration

    Be critical but constructive in your feedback. Point out both strengths and weaknesses.
    Do NOT rewrite the essay - only provide analysis and suggestions for improvement.
    """

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are an expert essay writer. Revise the following essay based on the provided feedback.

    Original Essay:
    {original_draft}

    Feedback:
    {reflection}

    Instructions:
    - Address all issues mentioned in the feedback
    - Improve clarity, coherence, and flow
    - Strengthen arguments and supporting evidence
    - Enhance the overall writing style
    - Maintain the original essay's core message and topic
    - The revised essay should be atleast 100 characters
    
    Provide ONLY the complete revised essay. Do not include any commentary, explanations, or notes about the changes made.
    """

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# Title: The Case for Government Regulation of Social Media Platforms
#
# In recent years, social media platforms have become integral to the fabric of modern society, influencing how individuals communicate, access information, and form opinions. With their vast reach and potent impact, these platforms possess substantial power over public discourse, sparking a contentious debate over whether they should be subject to government regulation. This essay contends that government regulation is necessary to ensure that social media platforms operate in a manner that protects individuals' rights, upholds democratic principles, and fosters a healthy information ecosystem.
#
# Firstly, government regulation is imperative to safeguard users' privacy and data protection rights. Social media platforms generate substantial revenue by collecting and monetizing users' personal information, raising significant privacy concerns. A notable example is the Cambridge Analytica scandal, where millions of Facebook users' data were harvested without consent, demonstrating the potential for misuse and abuse. Government oversight could establish stringent privacy regulations to prevent such breaches, requiring platforms to maintain transparency about data collection practices and ensuring users have control over their personal information. Implementing such regulations would not only protect individual privacy but also increase public trust in these platforms.
#
# In addition to privacy concerns, social media platforms often serve as breeding grounds for the spread of misinformation and disinformation, which can have dire consequences for democratic societies. False information can influence elections, undermine public health initiatives, and incite violence, as evidenced by the spread of conspiracy theories and misinformation during the COVID-19 pandemic. Although platforms have taken steps to address this issue, such as labeling false content and promoting credible sources, these efforts are often insufficient. Government regulation could mandate more comprehensive and rigorous mechanisms to identify and curb misinformation, ensuring a balanced approach that respects freedom of expression while prioritizing factual accuracy.
#
# Moreover, social media platforms have been criticized for their role in amplifying hate speech, extremism, and online harassment. The algorithms that govern these platforms prioritize content that maximizes user engagement, often favoring sensational and controversial material over balanced discourse. This dynamic has led to the proliferation of harmful content that can marginalize vulnerable groups and escalate social tensions. Government intervention could require platforms to develop and implement robust content moderation policies, promoting a safer and more inclusive online environment. Establishing clear standards for acceptable content and mechanisms for reporting and addressing violations would help prevent the spread of harmful rhetoric and protect individuals from online abuse.
#
# Critics of government regulation argue that it may stifle innovation and infringe upon free speech. While these concerns merit consideration, they must be balanced with the need to protect users and society at large. Thoughtful regulation can be designed to support innovation while delineating acceptable boundaries for platform operations. Additionally, the principle of free speech is not absolute; responsible regulation seeks to prevent harm and ensure that platforms contribute positively to society without compromising fundamental rights.
#
# In conclusion, the case for government regulation of social media platforms is compelling, given their profound impact on privacy, public discourse, and social dynamics. By establishing clear regulations and standards, governments can help safeguard users' rights, promote a truthful and respectful information environment, and mitigate the risks associated with unchecked digital power. Implementing such measures does not entail curtailing freedom or innovation but rather fostering a healthier alignment between technological advancement and democratic values. As social media continues to evolve, proactive and thoughtful regulation will be crucial to maximizing its benefits while minimizing its potential harm to society.
#
# 🧠 Feedback:
#
# Overall, the essay is well organized, following a clear five-part structure: an introduction that sets out the thesis, three body paragraphs each tackling a distinct rationale for regulation (privacy, misinformation, harmful content), a brief rebuttal of counterarguments, and a conclusion that restates the main points. This logical progression makes it easy for readers to follow the author’s line of reasoning. Transitions between sections are present but could be strengthened—for instance, signaling how the privacy discussion leads naturally into concerns about misinformation would create an even smoother flow.
#
# In terms of clarity and coherence, the writing generally communicates its ideas directly, and each paragraph stays on topic. However, the essay sometimes leans on broad generalizations (“social media platforms have become integral to the fabric of modern society”) that feel overused. More precise framing or concise topic sentences would sharpen the argument. Also, some terms—like “government regulation” and “social media platforms”—appear repeatedly; varying the language or using pronouns and synonyms could prevent redundancy and keep the prose engaging.
#
# The arguments are persuasive in that they invoke high-profile examples (the Cambridge Analytica scandal, COVID-19 misinformation) and clearly explain why unregulated platforms pose risks. Nonetheless, the essay would benefit from greater specificity: citing data on privacy breaches, referencing actual regulatory models (e.g., GDPR, the proposed Online Safety Bill), or summarizing scholarly findings on algorithmic amplification would lend extra authority. A more detailed exploration of how a balanced regulatory framework might be implemented—rather than simply asserting its feasibility—would bolster the essay’s practical weight.
#
# The writing style is formal and appropriately academic in tone, and the essay strikes a respectful balance between advocacy and acknowledgment of opposing views. Yet at times the diction is abstract and the sentences lengthy, which can dilute impact. Shortening complex sentences, favoring active over passive constructions (“Regulators could mandate…” instead of “Government regulation could be designed…”), and injecting more varied sentence rhythms would make the prose more dynamic and reader-friendly.
#
# Finally, while the core claims are solid, several areas could be expanded. The brief rebuttal of free-speech concerns feels tentative; a deeper engagement with First Amendment jurisprudence or comparative international approaches would strengthen it. The essay also omits discussion of potential downsides of regulation—such as regulatory capture or stifling small startups—which acknowledging and addressing would demonstrate critical depth. Adding concrete policy proposals or considering a tiered regulatory approach (differentiating based on platform size or function) would give the essay a more nuanced, solution-oriented finish.
#
# ✍️ Revised:
#
# Title: The Argument for Government Oversight of Social Media Platforms
#
# Social media platforms have transformed into pivotal components of contemporary society, revolutionizing the way individuals communicate, consume information, and form opinions. Their immense reach and influence over public discourse have ignited a heated debate on the necessity of government oversight. This essay argues that government regulation is crucial to ensuring that social media platforms respect individuals' rights, uphold democratic ideals, and support a healthy information ecosystem.
#
# To begin with, protecting users' privacy and data security is an imperative goal of regulation. These platforms earn considerable profits by collecting and selling users' personal information, which poses serious privacy risks. The Cambridge Analytica scandal, where Facebook users' data were exploited without consent, exemplifies the risk of data abuse. By enforcing robust privacy laws, akin to the European GDPR, governments can demand transparency in data collection practices, thereby empowering users with greater control over their personal information. Such regulations not only shield privacy but also reinforce public confidence in these platforms.
#
# The issue of misinformation further underscores the need for oversight. False information propagated on social media can meddle with elections, disrupt public health efforts, and incite violence, as seen with COVID-19 conspiracy theories. While platforms have made efforts to address misinformation by marking false content and promoting trusted sources, these measures often fall short. Government mandates could establish stringent and systematic frameworks to identify and mitigate misinformation, ensuring a balanced approach that upholds free speech while emphasizing factual accuracy.
#
# Moreover, platforms are often criticized for magnifying hate speech, extremism, and online harassment. Their algorithms tend to spotlight content that maximizes engagement, frequently prioritizing sensationalism over reasoned discourse. This dynamic can lead to the proliferation of harmful narratives that marginalize vulnerable communities and escalate social rifts. Government intervention could involve setting clear standards for content moderation, fostering a safer and more inclusive online community. Implementing mechanisms for promptly reporting and addressing harmful content would protect individuals from online harassment and hate speech.
#
# Detractors of regulation worry about stifling innovation and infringing on free expression. Though these concerns warrant attention, they must be weighed against the broader societal need for protection. Regulation can be crafted to foster innovation while delineating boundaries for acceptable platform activities. Furthermore, free speech is not limitless; well-considered regulation aims to prevent harm and ensure these platforms positively contribute to society, without undermining fundamental judicial freedoms. Delving into First Amendment considerations or reviewing international regulatory frameworks could provide valuable insights into balancing such aims.
#
# In closing, government regulation of social media platforms is justified by their significant impact on privacy, public discourse, and societal dynamics. By enacting well-defined regulations, governments can ensure the protection of users' rights, cultivate an informed and respectful information landscape, and mitigate the dangers of unchecked digital authority. Such measures are not about hindering freedom or stalling progress but about aligning technological innovation with democratic values. As social media continues to evolve, thoughtful and proactive regulation will be essential in maximizing benefits while minimizing societal risks. Exploring potential regulatory frameworks, including tiered approaches based on platform scale or function, can further refine and enhance the regulation strategy.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: The Case for Government Regulation of Social Media Platforms
#
# In recent years, social media platforms have become integral to the fabric of modern society, influencing how individuals communicate, access information, and form opinions. With their vast reach and potent impact, these platforms possess substantial power over public discourse, sparking a contentious debate over whether they should be subject to government regulation. This essay contends that government regulation is necessary to ensure that social media platforms operate in a manner that protects individuals' rights, upholds democratic principles, and fosters a healthy information ecosystem.
#
# Firstly, government regulation is imperative to safeguard users' privacy and data protection rights. Social media platforms generate substantial revenue by collecting and monetizing users' personal information, raising significant privacy concerns. A notable example is the Cambridge Analytica scandal, where millions of Facebook users' data were harvested without consent, demonstrating the potential for misuse and abuse. Government oversight could establish stringent privacy regulations to prevent such breaches, requiring platforms to maintain transparency about data collection practices and ensuring users have control over their personal information. Implementing such regulations would not only protect individual privacy but also increase public trust in these platforms.
#
# In addition to privacy concerns, social media platforms often serve as breeding grounds for the spread of misinformation and disinformation, which can have dire consequences for democratic societies. False information can influence elections, undermine public health initiatives, and incite violence, as evidenced by the spread of conspiracy theories and misinformation during the COVID-19 pandemic. Although platforms have taken steps to address this issue, such as labeling false content and promoting credible sources, these efforts are often insufficient. Government regulation could mandate more comprehensive and rigorous mechanisms to identify and curb misinformation, ensuring a balanced approach that respects freedom of expression while prioritizing factual accuracy.
#
# Moreover, social media platforms have been criticized for their role in amplifying hate speech, extremism, and online harassment. The algorithms that govern these platforms prioritize content that maximizes user engagement, often favoring sensational and controversial material over balanced discourse. This dynamic has led to the proliferation of harmful content that can marginalize vulnerable groups and escalate social tensions. Government intervention could require platforms to develop and implement robust content moderation policies, promoting a safer and more inclusive online environment. Establishing clear standards for acceptable content and mechanisms for reporting and addressing violations would help prevent the spread of harmful rhetoric and protect individuals from online abuse.
#
# Critics of government regulation argue that it may stifle innovation and infringe upon free speech. While these concerns merit consideration, they must be balanced with the need to protect users and society at large. Thoughtful regulation can be designed to support innovation while delineating acceptable boundaries for platform operations. Additionally, the principle of free speech is not absolute; responsible regulation seeks to prevent harm and ensure that platforms contribute positively to society without compromising fundamental rights.
#
# In conclusion, the case for government regulation of social media platforms is compelling, given their profound impact on privacy, public discourse, and social dynamics. By establishing clear regulations and standards, governments can help safeguard users' rights, promote a truthful and respectful information environment, and mitigate the risks associated with unchecked digital power. Implementing such measures does not entail curtailing freedom or innovation but rather fostering a healthier alignment between technological advancement and democratic values. As social media continues to evolve, proactive and thoughtful regulation will be crucial to maximizing its benefits while minimizing its potential harm to society.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Overall, the essay is well organized, following a clear five-part structure: an introduction that sets out the thesis, three body paragraphs each tackling a distinct rationale for regulation (privacy, misinformation, harmful content), a brief rebuttal of counterarguments, and a conclusion that restates the main points. This logical progression makes it easy for readers to follow the author’s line of reasoning. Transitions between sections are present but could be strengthened—for instance, signaling how the privacy discussion leads naturally into concerns about misinformation would create an even smoother flow.
#
# In terms of clarity and coherence, the writing generally communicates its ideas directly, and each paragraph stays on topic. However, the essay sometimes leans on broad generalizations (“social media platforms have become integral to the fabric of modern society”) that feel overused. More precise framing or concise topic sentences would sharpen the argument. Also, some terms—like “government regulation” and “social media platforms”—appear repeatedly; varying the language or using pronouns and synonyms could prevent redundancy and keep the prose engaging.
#
# The arguments are persuasive in that they invoke high-profile examples (the Cambridge Analytica scandal, COVID-19 misinformation) and clearly explain why unregulated platforms pose risks. Nonetheless, the essay would benefit from greater specificity: citing data on privacy breaches, referencing actual regulatory models (e.g., GDPR, the proposed Online Safety Bill), or summarizing scholarly findings on algorithmic amplification would lend extra authority. A more detailed exploration of how a balanced regulatory framework might be implemented—rather than simply asserting its feasibility—would bolster the essay’s practical weight.
#
# The writing style is formal and appropriately academic in tone, and the essay strikes a respectful balance between advocacy and acknowledgment of opposing views. Yet at times the diction is abstract and the sentences lengthy, which can dilute impact. Shortening complex sentences, favoring active over passive constructions (“Regulators could mandate…” instead of “Government regulation could be designed…”), and injecting more varied sentence rhythms would make the prose more dynamic and reader-friendly.
#
# Finally, while the core claims are solid, several areas could be expanded. The brief rebuttal of free-speech concerns feels tentative; a deeper engagement with First Amendment jurisprudence or comparative international approaches would strengthen it. The essay also omits discussion of potential downsides of regulation—such as regulatory capture or stifling small startups—which acknowledging and addressing would demonstrate critical depth. Adding concrete policy proposals or considering a tiered regulatory approach (differentiating based on platform size or function) would give the essay a more nuanced, solution-oriented finish.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: The Argument for Government Oversight of Social Media Platforms
#
# Social media platforms have transformed into pivotal components of contemporary society, revolutionizing the way individuals communicate, consume information, and form opinions. Their immense reach and influence over public discourse have ignited a heated debate on the necessity of government oversight. This essay argues that government regulation is crucial to ensuring that social media platforms respect individuals' rights, uphold democratic ideals, and support a healthy information ecosystem.
#
# To begin with, protecting users' privacy and data security is an imperative goal of regulation. These platforms earn considerable profits by collecting and selling users' personal information, which poses serious privacy risks. The Cambridge Analytica scandal, where Facebook users' data were exploited without consent, exemplifies the risk of data abuse. By enforcing robust privacy laws, akin to the European GDPR, governments can demand transparency in data collection practices, thereby empowering users with greater control over their personal information. Such regulations not only shield privacy but also reinforce public confidence in these platforms.
#
# The issue of misinformation further underscores the need for oversight. False information propagated on social media can meddle with elections, disrupt public health efforts, and incite violence, as seen with COVID-19 conspiracy theories. While platforms have made efforts to address misinformation by marking false content and promoting trusted sources, these measures often fall short. Government mandates could establish stringent and systematic frameworks to identify and mitigate misinformation, ensuring a balanced approach that upholds free speech while emphasizing factual accuracy.
#
# Moreover, platforms are often criticized for magnifying hate speech, extremism, and online harassment. Their algorithms tend to spotlight content that maximizes engagement, frequently prioritizing sensationalism over reasoned discourse. This dynamic can lead to the proliferation of harmful narratives that marginalize vulnerable communities and escalate social rifts. Government intervention could involve setting clear standards for content moderation, fostering a safer and more inclusive online community. Implementing mechanisms for promptly reporting and addressing harmful content would protect individuals from online harassment and hate speech.
#
# Detractors of regulation worry about stifling innovation and infringing on free expression. Though these concerns warrant attention, they must be weighed against the broader societal need for protection. Regulation can be crafted to foster innovation while delineating boundaries for acceptable platform activities. Furthermore, free speech is not limitless; well-considered regulation aims to prevent harm and ensure these platforms positively contribute to society, without undermining fundamental judicial freedoms. Delving into First Amendment considerations or reviewing international regulatory frameworks could provide valuable insights into balancing such aims.
#
# In closing, government regulation of social media platforms is justified by their significant impact on privacy, public discourse, and societal dynamics. By enacting well-defined regulations, governments can ensure the protection of users' rights, cultivate an informed and respectful information landscape, and mitigate the dangers of unchecked digital authority. Such measures are not about hindering freedom or stalling progress but about aligning technological innovation with democratic values. As social media continues to evolve, thoughtful and proactive regulation will be essential in maximizing benefits while minimizing societal risks. Exploring potential regulatory frameworks, including tiered approaches based on platform scale or function, can further refine and enhance the regulation strategy.</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
